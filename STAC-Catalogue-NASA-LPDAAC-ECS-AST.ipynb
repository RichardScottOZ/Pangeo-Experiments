# %%
import requests
import pandas as pd

import intake
import stackstac
import os

limit = 200

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
nasa = 'https://cmr.earthdata.nasa.gov/stac/'

response = requests.get(nasa)
json_response = response.json()

# %%
json_response = response.json()

# %%
#{'title': 'LARC_ASDC', 'rel': 'child', 'type': 'application/json', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC'}
collection_list = []
for collection in json_response["links"]:
    collection_list.append(collection)

# %%
datasets_list = []
for datasets in collection_list:
    url = datasets["href"]
    response = requests.get(url)
    json_response = response.json()
    datasets_list.append(json_response)

# %%
#need to handling paging when more than one, this just a quick look to narrow down which collection ASTER in
collection_list = []
dataset_list = []
for dataset in datasets_list:
    df = pd.DataFrame([dataset])
    collection_list.append(df)
    
    for link in dataset["links"]:
        ldf = pd.DataFrame([link])
        ldf["id"] = dataset["id"]
        ldf = ldf.loc[ldf["rel"] == "child"]
        dataset_list.append(ldf)
        #print(link)
        if "next" in link["rel"]:
            #build to handle this
            print(link)
            pass
    
dfCollections = pd.concat(collection_list)    

dfDataset = pd.concat(dataset_list)
# Out:
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/SEDAC?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD?page=2'}
# {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC?page=2'}

# %%
dfCollections.head()
# Out:
#           id      title                 description     type  stac_version  \
# 0  LARC_ASDC  LARC_ASDC  Root catalog for LARC_ASDC  Catalog  1.0.0-beta.2
# 0  USGS_EROS  USGS_EROS  Root catalog for USGS_EROS  Catalog  1.0.0-beta.2
# 0        ESA        ESA        Root catalog for ESA  Catalog  1.0.0-beta.2
# 0       GHRC       GHRC       Root catalog for GHRC  Catalog  1.0.0-beta.2
# 0      LAADS      LAADS      Root catalog for LAADS  Catalog  1.0.0-beta.2
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
#
#                                           conformsTo
# 0  [https://api.stacspec.org/v1.0.0-beta.1/core, ...
# 0  [https://api.stacspec.org/v1.0.0-beta.1/core, ...
# 0  [https://api.stacspec.org/v1.0.0-beta.1/core, ...
# 0  [https://api.stacspec.org/v1.0.0-beta.1/core, ...
# 0  [https://api.stacspec.org/v1.0.0-beta.1/core, ...

# %%
dfDataset.head()
# Out:
#      rel                                               href title  \
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
#
#                type         id method
# 0  application/json  LARC_ASDC    NaN
# 0  application/json  LARC_ASDC    NaN
# 0  application/json  LARC_ASDC    NaN
# 0  application/json  LARC_ASDC    NaN
# 0  application/json  LARC_ASDC    NaN

# %%
dfDataset
# Out:
#      rel                                               href title  \
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_EROS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ESA/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LAADS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OB_DAAC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ISRO/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GES_DISC/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASF/collec...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/OMINRT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/EUMETSAT/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NCCS/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDCV0/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/PODAAC/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SCIOPS/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEMODIS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/CDDIS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/JAXA/colle...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/AU_AADC/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LM_FIRMS/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/SEDAC/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/USGS_LTA/c...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASIPS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASIPS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASIPS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ASIPS/coll...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/POCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/MOPITT/col...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
#
#                type          id method
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   LARC_ASDC    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json   USGS_EROS    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json         ESA    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json       LAADS    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json     OB_DAAC    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json        ISRO    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json    GES_DISC    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json         ASF    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json      OMINRT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json    EUMETSAT    NaN
# 0  application/json        NCCS    NaN
# 0  application/json        NCCS    NaN
# 0  application/json        NCCS    NaN
# 0  application/json        NCCS    NaN
# 0  application/json        NCCS    NaN
# 0  application/json        NCCS    NaN
# 0  application/json        NCCS    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json     NSIDCV0    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json      PODAAC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json        LARC    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json      SCIOPS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json  LANCEMODIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json       CDDIS    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json        JAXA    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json     AU_AADC    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   NSIDC_ECS    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json   ORNL_DAAC    NaN
# 0  application/json    LM_FIRMS    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json       SEDAC    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json  LANCEAMSR2    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json   NOAA_NCEI    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json    USGS_LTA    NaN
# 0  application/json       ASIPS    NaN
# 0  application/json       ASIPS    NaN
# 0  application/json       ASIPS    NaN
# 0  application/json       ASIPS    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json     POCLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json  ORNL_CLOUD    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json   GHRC_DAAC    NaN
# 0  application/json      MOPITT    NaN
# 0  application/json     LPCLOUD    NaN
# 0  application/json     LPCLOUD    NaN
# 0  application/json     LPCLOUD    NaN

# %%
dfDataset.loc[dfDataset.href.str.contains("AST")]
# Out:
#      rel                                               href title  \
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
#
#                type          id method
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json  LPDAAC_ECS    NaN
# 0  application/json     LPCLOUD    NaN

# %%
cat2 = intake.open_stac_catalog(f'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections?limit={limit}')
col_info2 = pd.DataFrame(cat2.metadata['collections'])
col_info2.head(1)
# Out:
#               id  stac_version       license  \
# 0  AST14DEM.v003  1.0.0-beta.2  not-provided
#
#                                 title        type  \
# 0  ASTER Digital Elevation Model V003  Collection
#
#                                          description  \
# 0  The ASTER Digital Elevation Model (AST14DEM) p...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
#
#                                               extent
# 0  {'crs': 'http://www.opengis.net/def/crs/OGC/1....

# %%
col_info2
# Out:
#                           id  stac_version       license  \
# 0              AST14DEM.v003  1.0.0-beta.2  not-provided
# 1              AST_L1AE.v003  1.0.0-beta.2  not-provided
# 2              AST_L1BE.v003  1.0.0-beta.2  not-provided
# 3          ASTGTM_NUMNC.v003  1.0.0-beta.2  not-provided
# 4             ASTGTM_NC.v003  1.0.0-beta.2  not-provided
# 5                 AG1km.v003  1.0.0-beta.2  not-provided
# 6                 AG100.v003  1.0.0-beta.2  not-provided
# 7              AG5KMMOH.v041  1.0.0-beta.2  not-provided
# 8          ASTWBD_ATTNC.v001  1.0.0-beta.2  not-provided
# 9             ASTWBD_NC.v001  1.0.0-beta.2  not-provided
# 10               ASTWBD.v001  1.0.0-beta.2  not-provided
# 11              AST_L1A.v003  1.0.0-beta.2  not-provided
# 12              AST_L1B.v003  1.0.0-beta.2  not-provided
# 13               AST_05.v003  1.0.0-beta.2  not-provided
# 14             AST_09XT.v003  1.0.0-beta.2  not-provided
# 15              AST_09T.v003  1.0.0-beta.2  not-provided
# 16               AST_09.v003  1.0.0-beta.2  not-provided
# 17               AST_07.v003  1.0.0-beta.2  not-provided
# 18             AST_07XT.v003  1.0.0-beta.2  not-provided
# 19               AST_08.v003  1.0.0-beta.2  not-provided
# 20              AST_L1T.v003  1.0.0-beta.2  not-provided
# 21             AST14DMO.v003  1.0.0-beta.2  not-provided
# 22             AST14OTH.v003  1.0.0-beta.2  not-provided
# 23            CAM5K30CF.v001  1.0.0-beta.2  not-provided
# 24            CAM5K30CF.v002  1.0.0-beta.2  not-provided
# 25            CAM5K30EM.v001  1.0.0-beta.2  not-provided
# 26            CAM5K30EM.v002  1.0.0-beta.2  not-provided
# 27            CAM5K30UC.v001  1.0.0-beta.2  not-provided
# 28            CAM5K30UC.v002  1.0.0-beta.2  not-provided
# 29             ECO1BRAD.v001  1.0.0-beta.2  not-provided
# 30             ECO1BATT.v001  1.0.0-beta.2  not-provided
# 31              ECO2CLD.v001  1.0.0-beta.2  not-provided
# 32        ECO4ESIALEXIU.v001  1.0.0-beta.2  not-provided
# 33         ECO4ESIPTJPL.v001  1.0.0-beta.2  not-provided
# 34         ECO3ETALEXIU.v001  1.0.0-beta.2  not-provided
# 35          ECO3ETPTJPL.v001  1.0.0-beta.2  not-provided
# 36             ECO1BGEO.v001  1.0.0-beta.2  not-provided
# 37            ECO3ANCQA.v001  1.0.0-beta.2  not-provided
# 38             ECO2LSTE.v001  1.0.0-beta.2  not-provided
# 39          ECO1BMAPRAD.v001  1.0.0-beta.2  not-provided
# 40              ECO4WUE.v001  1.0.0-beta.2  not-provided
# 41               GLCHMK.v001  1.0.0-beta.2  not-provided
# 42               GLCHMT.v001  1.0.0-beta.2  not-provided
# 43               GLDTMK.v001  1.0.0-beta.2  not-provided
# 44               GLDTMT.v001  1.0.0-beta.2  not-provided
# 45             GEDI01_B.v001  1.0.0-beta.2  not-provided
# 46             GEDI01_B.v002  1.0.0-beta.2  not-provided
# 47             GEDI02_A.v001  1.0.0-beta.2  not-provided
# 48             GEDI02_A.v002  1.0.0-beta.2  not-provided
# 49             GEDI02_B.v001  1.0.0-beta.2  not-provided
# 50             GEDI02_B.v002  1.0.0-beta.2  not-provided
# 51           GEOLST4KHR.v001  1.0.0-beta.2  not-provided
# 52            GFSAD1KCD.v001  1.0.0-beta.2  not-provided
# 53            GFSAD1KCM.v001  1.0.0-beta.2  not-provided
# 54          GFSAD30NACE.v001  1.0.0-beta.2  not-provided
# 55          GFSAD30AFCE.v001  1.0.0-beta.2  not-provided
# 56    GFSAD30AUNZCNMOCE.v001  1.0.0-beta.2  not-provided
# 57   GFSAD30EUCEARUMECE.v001  1.0.0-beta.2  not-provided
# 58          GFSAD30SACE.v001  1.0.0-beta.2  not-provided
# 59     GFSAD30SAAFGIRCE.v001  1.0.0-beta.2  not-provided
# 60         GFSAD30SEACE.v001  1.0.0-beta.2  not-provided
# 61           GFSAD30VAL.v001  1.0.0-beta.2  not-provided
# 62            GFCC30FCC.v001  1.0.0-beta.2  not-provided
# 63             GFCC30SR.v001  1.0.0-beta.2  not-provided
# 64             GFCC30TC.v003  1.0.0-beta.2  not-provided
# 65             GFCC30WC.v001  1.0.0-beta.2  not-provided
# 66           GHISACASIA.v001  1.0.0-beta.2  not-provided
# 67           GHISACONUS.v001  1.0.0-beta.2  not-provided
# 68              VCF5KYR.v001  1.0.0-beta.2  not-provided
# 69             MYD17A2H.v006  1.0.0-beta.2  not-provided
# 70             MYD17A2H.v061  1.0.0-beta.2  not-provided
# 71           MYD17A2HGF.v006  1.0.0-beta.2  not-provided
# 72           MYD17A2HGF.v061  1.0.0-beta.2  not-provided
# 73                MYD21.v006  1.0.0-beta.2  not-provided
# 74                MYD21.v061  1.0.0-beta.2  not-provided
# 75              MYD21C2.v061  1.0.0-beta.2  not-provided
# 76              MYD21A2.v006  1.0.0-beta.2  not-provided
# 77              MYD21A2.v061  1.0.0-beta.2  not-provided
# 78              MYD21C1.v061  1.0.0-beta.2  not-provided
# 79             MYD21A1D.v006  1.0.0-beta.2  not-provided
# 80             MYD21A1D.v061  1.0.0-beta.2  not-provided
# 81             MYD21A1N.v006  1.0.0-beta.2  not-provided
# 82             MYD21A1N.v061  1.0.0-beta.2  not-provided
# 83              MYD21C3.v061  1.0.0-beta.2  not-provided
# 84             MYD11_L2.v006  1.0.0-beta.2  not-provided
# 85             MYD11_L2.v061  1.0.0-beta.2  not-provided
# 86              MYD11C2.v006  1.0.0-beta.2  not-provided
# 87              MYD11C2.v061  1.0.0-beta.2  not-provided
# 88              MYD11A2.v006  1.0.0-beta.2  not-provided
# 89              MYD11A2.v061  1.0.0-beta.2  not-provided
# 90              MYD11B2.v006  1.0.0-beta.2  not-provided
# 91              MYD11B2.v061  1.0.0-beta.2  not-provided
# 92              MYD11C1.v006  1.0.0-beta.2  not-provided
# 93              MYD11C1.v061  1.0.0-beta.2  not-provided
# 94              MYD11A1.v006  1.0.0-beta.2  not-provided
# 95              MYD11A1.v061  1.0.0-beta.2  not-provided
# 96              MYD11B1.v006  1.0.0-beta.2  not-provided
# 97              MYD11B1.v061  1.0.0-beta.2  not-provided
# 98              MYD11C3.v006  1.0.0-beta.2  not-provided
# 99              MYD11C3.v061  1.0.0-beta.2  not-provided
# 100             MYD11B3.v006  1.0.0-beta.2  not-provided
# 101             MYD11B3.v061  1.0.0-beta.2  not-provided
# 102            MYD15A2H.v006  1.0.0-beta.2  not-provided
# 103            MYD15A2H.v061  1.0.0-beta.2  not-provided
# 104             MYD16A2.v006  1.0.0-beta.2  not-provided
# 105             MYD16A2.v061  1.0.0-beta.2  not-provided
# 106           MYD16A2GF.v006  1.0.0-beta.2  not-provided
# 107           MYD16A2GF.v061  1.0.0-beta.2  not-provided
# 108           MYD16A3GF.v006  1.0.0-beta.2  not-provided
# 109           MYD16A3GF.v061  1.0.0-beta.2  not-provided
# 110             MYD16A3.v061  1.0.0-beta.2  not-provided
# 111          MYD17A3HGF.v006  1.0.0-beta.2  not-provided
# 112          MYD17A3HGF.v061  1.0.0-beta.2  not-provided
# 113            MYD17A3H.v006  1.0.0-beta.2  not-provided
# 114            MYD17A3H.v061  1.0.0-beta.2  not-provided
# 115             MYDOCGA.v006  1.0.0-beta.2  not-provided
# 116             MYD09Q1.v006  1.0.0-beta.2  not-provided
# 117             MYD09Q1.v061  1.0.0-beta.2  not-provided
# 118             MYD09A1.v006  1.0.0-beta.2  not-provided
# 119             MYD09A1.v061  1.0.0-beta.2  not-provided
# 120             MYD09GA.v006  1.0.0-beta.2  not-provided
# 121             MYD09GA.v061  1.0.0-beta.2  not-provided
# 122             MYD09GQ.v006  1.0.0-beta.2  not-provided
# 123             MYD09GQ.v061  1.0.0-beta.2  not-provided
# 124            MYD09CMG.v006  1.0.0-beta.2  not-provided
# 125            MYD09CMG.v061  1.0.0-beta.2  not-provided
# 126               MYD14.v006  1.0.0-beta.2  not-provided
# 127               MYD14.v061  1.0.0-beta.2  not-provided
# 128             MYD14A2.v006  1.0.0-beta.2  not-provided
# 129             MYD14A2.v061  1.0.0-beta.2  not-provided
# 130             MYD14A1.v006  1.0.0-beta.2  not-provided
# 131             MYD14A1.v061  1.0.0-beta.2  not-provided
# 132             MYDTBGA.v006  1.0.0-beta.2  not-provided
# 133             MYD13C1.v006  1.0.0-beta.2  not-provided
# 134             MYD13C1.v061  1.0.0-beta.2  not-provided
# 135             MYD13A2.v006  1.0.0-beta.2  not-provided
# 136             MYD13A2.v061  1.0.0-beta.2  not-provided
# 137             MYD13Q1.v006  1.0.0-beta.2  not-provided
# 138             MYD13Q1.v061  1.0.0-beta.2  not-provided
# 139             MYD13A1.v006  1.0.0-beta.2  not-provided
# 140             MYD13A1.v061  1.0.0-beta.2  not-provided
# 141             MYD13C2.v006  1.0.0-beta.2  not-provided
# 142             MYD13C2.v061  1.0.0-beta.2  not-provided
# 143             MYD13A3.v006  1.0.0-beta.2  not-provided
# 144             MYD13A3.v061  1.0.0-beta.2  not-provided
# 145             MYD28C2.v061  1.0.0-beta.2  not-provided
# 146            MOD17A2H.v006  1.0.0-beta.2  not-provided
# 147            MOD17A2H.v061  1.0.0-beta.2  not-provided
# 148          MOD17A2HGF.v006  1.0.0-beta.2  not-provided
# 149          MOD17A2HGF.v061  1.0.0-beta.2  not-provided
# 150               MOD21.v006  1.0.0-beta.2  not-provided
# 151               MOD21.v061  1.0.0-beta.2  not-provided
# 152             MOD21C2.v061  1.0.0-beta.2  not-provided
# 153             MOD21A2.v006  1.0.0-beta.2  not-provided
# 154             MOD21A2.v061  1.0.0-beta.2  not-provided
# 155             MOD21C1.v061  1.0.0-beta.2  not-provided
# 156            MOD21A1D.v006  1.0.0-beta.2  not-provided
# 157            MOD21A1D.v061  1.0.0-beta.2  not-provided
# 158            MOD21A1N.v006  1.0.0-beta.2  not-provided
# 159            MOD21A1N.v061  1.0.0-beta.2  not-provided
# 160             MOD21C3.v061  1.0.0-beta.2  not-provided
# 161            MOD11_L2.v006  1.0.0-beta.2  not-provided
# 162            MOD11_L2.v061  1.0.0-beta.2  not-provided
# 163             MOD11C2.v006  1.0.0-beta.2  not-provided
# 164             MOD11C2.v061  1.0.0-beta.2  not-provided
# 165             MOD11A2.v006  1.0.0-beta.2  not-provided
# 166             MOD11A2.v061  1.0.0-beta.2  not-provided
# 167             MOD11B2.v006  1.0.0-beta.2  not-provided
# 168             MOD11B2.v061  1.0.0-beta.2  not-provided
# 169             MOD11C1.v006  1.0.0-beta.2  not-provided
# 170             MOD11C1.v061  1.0.0-beta.2  not-provided
# 171             MOD11A1.v006  1.0.0-beta.2  not-provided
# 172             MOD11A1.v061  1.0.0-beta.2  not-provided
# 173             MOD11B1.v006  1.0.0-beta.2  not-provided
# 174             MOD11B1.v061  1.0.0-beta.2  not-provided
# 175             MOD11C3.v006  1.0.0-beta.2  not-provided
# 176             MOD11C3.v061  1.0.0-beta.2  not-provided
# 177             MOD11B3.v006  1.0.0-beta.2  not-provided
# 178             MOD11B3.v061  1.0.0-beta.2  not-provided
# 179              MOD44W.v006  1.0.0-beta.2  not-provided
# 180            MOD15A2H.v006  1.0.0-beta.2  not-provided
# 181            MOD15A2H.v061  1.0.0-beta.2  not-provided
# 182             MOD16A2.v006  1.0.0-beta.2  not-provided
# 183             MOD16A2.v061  1.0.0-beta.2  not-provided
# 184           MOD16A2GF.v006  1.0.0-beta.2  not-provided
# 185           MOD16A2GF.v061  1.0.0-beta.2  not-provided
# 186           MOD16A3GF.v006  1.0.0-beta.2  not-provided
# 187           MOD16A3GF.v061  1.0.0-beta.2  not-provided
# 188             MOD16A3.v061  1.0.0-beta.2  not-provided
# 189          MOD17A3HGF.v006  1.0.0-beta.2  not-provided
# 190          MOD17A3HGF.v061  1.0.0-beta.2  not-provided
# 191             MOD17A3.v055  1.0.0-beta.2  not-provided
# 192            MOD17A3H.v006  1.0.0-beta.2  not-provided
# 193            MOD17A3H.v061  1.0.0-beta.2  not-provided
# 194             MODOCGA.v006  1.0.0-beta.2  not-provided
# 195             MOD09Q1.v006  1.0.0-beta.2  not-provided
# 196             MOD09Q1.v061  1.0.0-beta.2  not-provided
# 197             MOD09A1.v006  1.0.0-beta.2  not-provided
# 198             MOD09A1.v061  1.0.0-beta.2  not-provided
# 199             MOD09GA.v006  1.0.0-beta.2  not-provided
#
#                                                  title        type  \
# 0                   ASTER Digital Elevation Model V003  Collection
# 1    ASTER Expedited L1A Reconstructed Unprocessed ...  Collection
# 2    ASTER Expedited L1B Registered Radiance at the...  Collection
# 3    ASTER Global Digital Elevation Model Attribute...  Collection
# 4     ASTER Global Digital Elevation Model NetCDF V003  Collection
# 5    ASTER Global Emissivity Dataset, 1 kilometer, ...  Collection
# 6    ASTER Global Emissivity Dataset, 100 meter, HD...  Collection
# 7    ASTER Global Emissivity Dataset, Monthly, 0.05...  Collection
# 8    ASTER Global Water Bodies Database Attributes ...  Collection
# 9       ASTER Global Water Bodies Database NetCDF V001  Collection
# 10             ASTER Global Water Bodies Database V001  Collection
# 11   ASTER L1A Reconstructed Unprocessed Instrument...  Collection
# 12    ASTER L1B Registered Radiance at the Sensor V003  Collection
# 13                    ASTER L2 Surface Emissivity V003  Collection
# 14   ASTER L2 Surface Radiance - VNIR and Crosstalk...  Collection
# 15                  ASTER L2 Surface Radiance TIR V003  Collection
# 16        ASTER L2 Surface Radiance VNIR and SWIR V003  Collection
# 17   ASTER L2 Surface Reflectance SWIR and ASTER L2...  Collection
# 18   ASTER L2 Surface Reflectance VNIR and Crosstal...  Collection
# 19                   ASTER L2 Surface Temperature V003  Collection
# 20   ASTER Level 1 precision terrain corrected regi...  Collection
# 21   ASTER Orthorectified Digital Elevation Model (...  Collection
# 22   ASTER Registered Radiance at the Sensor - Orth...  Collection
# 23   Combined ASTER and MODIS Emissivity database o...  Collection
# 24   Combined ASTER and MODIS Emissivity database o...  Collection
# 25   Combined ASTER and MODIS Emissivity database o...  Collection
# 26   Combined ASTER and MODIS Emissivity database o...  Collection
# 27   Combined ASTER and MODIS Emissivity database o...  Collection
# 28   Combined ASTER and MODIS Emissivity database o...  Collection
# 29   ECOSTRESS At-sensor Calibrated Radiance Daily ...  Collection
# 30        ECOSTRESS Attitude Daily L1B Global 70m V001  Collection
# 31       ECOSTRESS Cloud Mask Daily L2 Global 70m V001  Collection
# 32   ECOSTRESS Evaporative Stress Index dis-ALEXI U...  Collection
# 33   ECOSTRESS Evaporative Stress Index PT-JPL Dail...  Collection
# 34   ECOSTRESS Evapotranspiration dis-ALEXI USDA Da...  Collection
# 35   ECOSTRESS Evapotranspiration PT-JPL Daily L3 G...  Collection
# 36     ECOSTRESS Geolocation Daily L1B Global 70m V001  Collection
# 37   ECOSTRESS L3/L4 Ancillary data Quality Assuran...  Collection
# 38   ECOSTRESS Land Surface Temperature and Emissiv...  Collection
# 39   ECOSTRESS Resampled Radiance Daily L1B Global ...  Collection
# 40   ECOSTRESS Water Use Efficiency Daily L4 Global...  Collection
# 41                 G-LiHT Canopy Height Model KML V001  Collection
# 42                     G-LiHT Canopy Height Model V001  Collection
# 43               G-LiHT Digital Terrain Model KML V001  Collection
# 44                   G-LiHT Digital Terrain Model V001  Collection
# 45   GEDI L1B Geolocated Waveform Data Global Footp...  Collection
# 46   GEDI L1B Geolocated Waveform Data Global Footp...  Collection
# 47   GEDI L2A Elevation and Height Metrics Data Glo...  Collection
# 48   GEDI L2A Elevation and Height Metrics Data Glo...  Collection
# 49   GEDI L2B Canopy Cover and Vertical Profile Met...  Collection
# 50   GEDI L2B Canopy Cover and Vertical Profile Met...  Collection
# 51   Geostationary Earth Orbit Land Surface Tempera...  Collection
# 52   Global Food Security Support Analysis Data (GF...  Collection
# 53   Global Food Security Support Analysis Data (GF...  Collection
# 54   Global Food Security-support Analysis Data (GF...  Collection
# 55   Global Food Security-support Analysis Data (GF...  Collection
# 56   Global Food Security-support Analysis Data (GF...  Collection
# 57   Global Food Security-support Analysis Data (GF...  Collection
# 58   Global Food Security-support Analysis Data (GF...  Collection
# 59   Global Food Security-support Analysis Data (GF...  Collection
# 60   Global Food Security-support Analysis Data (GF...  Collection
# 61   Global Food Security-support Analysis Data (GF...  Collection
# 62   Global Forest Cover Change Forest Cover Change...  Collection
# 63   Global Forest Cover Change Surface Reflectance...  Collection
# 64   Global Forest Cover Change Tree Cover Multi-Ye...  Collection
# 65   Global Forest Cover Change Water Cover 2000 Gl...  Collection
# 66   Global Hyperspectral Imaging Spectral-library ...  Collection
# 67   Global Hyperspectral Imaging Spectral-library ...  Collection
# 68   MEaSUREs Vegetation Continuous Fields (VCF) Ye...  Collection
# 69   MODIS/Aqua Gross Primary Productivity 8-Day L4...  Collection
# 70   MODIS/Aqua Gross Primary Productivity 8-Day L4...  Collection
# 71   MODIS/Aqua Gross Primary Productivity Gap-Fill...  Collection
# 72   MODIS/Aqua Gross Primary Productivity Gap-Fill...  Collection
# 73   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 74   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 75   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 76   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 77   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 78   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 79   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 80   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 81   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 82   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 83   MODIS/Aqua Land Surface Temperature/3-Band Emi...  Collection
# 84   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 85   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 86   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 87   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 88   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 89   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 90   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 91   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 92   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 93   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 94   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 95   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 96   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 97   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 98   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 99   MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 100  MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 101  MODIS/Aqua Land Surface Temperature/Emissivity...  Collection
# 102  MODIS/Aqua Leaf Area Index/FPAR 8-Day L4 Globa...  Collection
# 103  MODIS/Aqua Leaf Area Index/FPAR 8-Day L4 Globa...  Collection
# 104  MODIS/Aqua Net Evapotranspiration 8-Day L4 Glo...  Collection
# 105  MODIS/Aqua Net Evapotranspiration 8-Day L4 Glo...  Collection
# 106  MODIS/Aqua Net Evapotranspiration Gap-Filled 8...  Collection
# 107  MODIS/Aqua Net Evapotranspiration Gap-Filled 8...  Collection
# 108  MODIS/Aqua Net Evapotranspiration Gap-Filled Y...  Collection
# 109  MODIS/Aqua Net Evapotranspiration Gap-Filled Y...  Collection
# 110  MODIS/Aqua Net Evapotranspiration Yearly L4 Gl...  Collection
# 111  MODIS/Aqua Net Primary Production Gap-Filled Y...  Collection
# 112  MODIS/Aqua Net Primary Production Gap-Filled Y...  Collection
# 113  MODIS/Aqua Net Primary Production Yearly L4 Gl...  Collection
# 114  MODIS/Aqua Net Primary Production Yearly L4 Gl...  Collection
# 115  MODIS/Aqua Ocean Reflectance Daily L2G-Lite Gl...  Collection
# 116  MODIS/Aqua Surface Reflectance 8-Day L3 Global...  Collection
# 117  MODIS/Aqua Surface Reflectance 8-Day L3 Global...  Collection
# 118  MODIS/Aqua Surface Reflectance 8-Day L3 Global...  Collection
# 119  MODIS/Aqua Surface Reflectance 8-Day L3 Global...  Collection
# 120  MODIS/Aqua Surface Reflectance Daily L2G Globa...  Collection
# 121  MODIS/Aqua Surface Reflectance Daily L2G Globa...  Collection
# 122  MODIS/Aqua Surface Reflectance Daily L2G Globa...  Collection
# 123  MODIS/Aqua Surface Reflectance Daily L2G Globa...  Collection
# 124  MODIS/Aqua Surface Reflectance Daily L3 Global...  Collection
# 125  MODIS/Aqua Surface Reflectance Daily L3 Global...  Collection
# 126  MODIS/Aqua Thermal Anomalies/Fire 5-Min L2 Swa...  Collection
# 127  MODIS/Aqua Thermal Anomalies/Fire 5-Min L2 Swa...  Collection
# 128  MODIS/Aqua Thermal Anomalies/Fire 8-Day L3 Glo...  Collection
# 129  MODIS/Aqua Thermal Anomalies/Fire 8-Day L3 Glo...  Collection
# 130  MODIS/Aqua Thermal Anomalies/Fire Daily L3 Glo...  Collection
# 131  MODIS/Aqua Thermal Anomalies/Fire Daily L3 Glo...  Collection
# 132  MODIS/Aqua Thermal Bands Daily L2G-Lite Global...  Collection
# 133  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 134  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 135  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 136  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 137  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 138  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 139  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 140  MODIS/Aqua Vegetation Indices 16-Day L3 Global...  Collection
# 141  MODIS/Aqua Vegetation Indices Monthly L3 Globa...  Collection
# 142  MODIS/Aqua Vegetation Indices Monthly L3 Globa...  Collection
# 143  MODIS/Aqua Vegetation Indices Monthly L3 Globa...  Collection
# 144  MODIS/Aqua Vegetation Indices Monthly L3 Globa...  Collection
# 145    MODIS/Aqua Water Reservoir 8-Day L3 Global V061  Collection
# 146  MODIS/Terra Gross Primary Productivity 8-Day L...  Collection
# 147  MODIS/Terra Gross Primary Productivity 8-Day L...  Collection
# 148  MODIS/Terra Gross Primary Productivity Gap-Fil...  Collection
# 149  MODIS/Terra Gross Primary Productivity Gap-Fil...  Collection
# 150  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 151  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 152  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 153  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 154  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 155  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 156  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 157  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 158  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 159  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 160  MODIS/Terra Land Surface Temperature/3-Band Em...  Collection
# 161  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 162  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 163  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 164  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 165  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 166  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 167  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 168  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 169  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 170  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 171  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 172  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 173  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 174  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 175  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 176  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 177  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 178  MODIS/Terra Land Surface Temperature/Emissivit...  Collection
# 179  MODIS/Terra Land Water Mask Derived from MODIS...  Collection
# 180  MODIS/Terra Leaf Area Index/FPAR 8-Day L4 Glob...  Collection
# 181  MODIS/Terra Leaf Area Index/FPAR 8-Day L4 Glob...  Collection
# 182  MODIS/Terra Net Evapotranspiration 8-Day L4 Gl...  Collection
# 183  MODIS/Terra Net Evapotranspiration 8-Day L4 Gl...  Collection
# 184  MODIS/Terra Net Evapotranspiration Gap-Filled ...  Collection
# 185  MODIS/Terra Net Evapotranspiration Gap-Filled ...  Collection
# 186  MODIS/Terra Net Evapotranspiration Gap-Filled ...  Collection
# 187  MODIS/Terra Net Evapotranspiration Gap-Filled ...  Collection
# 188  MODIS/Terra Net Evapotranspiration Yearly L4 G...  Collection
# 189  MODIS/Terra Net Primary Production Gap-Filled ...  Collection
# 190  MODIS/Terra Net Primary Production Gap-Filled ...  Collection
# 191  MODIS/Terra Net Primary Production Yearly L4 G...  Collection
# 192  MODIS/Terra Net Primary Production Yearly L4 G...  Collection
# 193  MODIS/Terra Net Primary Production Yearly L4 G...  Collection
# 194  MODIS/Terra Ocean Reflectance Daily L2G-Lite G...  Collection
# 195  MODIS/Terra Surface Reflectance 8-Day L3 Globa...  Collection
# 196  MODIS/Terra Surface Reflectance 8-Day L3 Globa...  Collection
# 197  MODIS/Terra Surface Reflectance 8-Day L3 Globa...  Collection
# 198  MODIS/Terra Surface Reflectance 8-Day L3 Globa...  Collection
# 199  MODIS/Terra Surface Reflectance Daily L2G Glob...  Collection
#
#                                            description  \
# 0    The ASTER Digital Elevation Model (AST14DEM) p...
# 1    The Advanced Spaceborne Thermal Emission and R...
# 2    The Advanced Spaceborne Thermal Emission and R...
# 3    The ASTER Global Digital Elevation Model (GDEM...
# 4    The ASTER Global Digital Elevation Model (GDEM...
# 5    Advanced Spaceborne Thermal Emission and Refle...
# 6    Advanced Spaceborne Thermal Emission and Refle...
# 7    Advanced Spaceborne Thermal Emission and Refle...
# 8    The ASTER Global Water Bodies Database (ASTWBD...
# 9    The ASTER Global Water Bodies Database (ASTWBD...
# 10   The ASTER Global Water Bodies Database (ASTWBD...
# 11   The Advanced Spaceborne Thermal Emission and R...
# 12   The Advanced Spaceborne Thermal Emission and R...
# 13   The ASTER L2 Surface Emissivity is an on-deman...
# 14   The ASTER Surface Radiance VNIR and Crosstalk ...
# 15   The ASTER Surface Radiance TIR (AST_09T) is ge...
# 16   The ASTER Surface Radiance VNIR and SWIR (AST_...
# 17   The ASTER Surface Reflectance VNIR and SWIR (A...
# 18   The ASTER Surface Reflectance VNIR and Crossta...
# 19   The ASTER Surface Kinetic Temperature (AST_08)...
# 20   The Advanced Spaceborne Thermal Emission and R...
# 21   The ASTER Digital Elevation Model and Orthorec...
# 22   The ASTER Orthorectified Registered Radiance a...
# 23   The NASA Making Earth System Data Records for ...
# 24   The NASA Making Earth System Data Records for ...
# 25   The NASA Making Earth System Data Records for ...
# 26   The NASA Making Earth System Data Records for ...
# 27   The NASA Making Earth System Data Records for ...
# 28   The NASA Making Earth System Data Records for ...
# 29   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 30   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 31   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 32   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 33   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 34   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 35   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 36   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 37   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 38   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 39   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 40   The ECOsystem Spaceborne Thermal Radiometer Ex...
# 41   Goddard’s LiDAR, Hyperspectral, and Thermal Im...
# 42   Goddard’s LiDAR, Hyperspectral, and Thermal Im...
# 43   Goddard’s LiDAR, Hyperspectral, and Thermal Im...
# 44   Goddard’s LiDAR, Hyperspectral, and Thermal Im...
# 45   The GEDI Spatial Querying and Subsetting Quick...
# 46   The Global Ecosystem Dynamics Investigation (G...
# 47   The GEDI Spatial Querying and Subsetting Quick...
# 48   The Global Ecosystem Dynamics Investigation (G...
# 49   The GEDI Spatial Querying and Subsetting Quick...
# 50   The Global Ecosystem Dynamics Investigation (G...
# 51   The NASA Making Earth System Data Records for ...
# 52   The NASA Making Earth System Data Records for ...
# 53   The NASA Making Earth System Data Records for ...
# 54   The NASA Making Earth System Data Records for ...
# 55   The NASA Making Earth System Data Records for ...
# 56   The NASA Making Earth System Data Records for ...
# 57   The NASA Making Earth System Data Records for ...
# 58   The NASA Making Earth System Data Records for ...
# 59   The NASA Making Earth System Data Records for ...
# 60   The NASA Making Earth System Data Records for ...
# 61   The NASA Making Earth System Data Records for ...
# 62   The Land Processes Distributed Active Archive ...
# 63   The Land Processes Distributed Active Archive ...
# 64   The Land Processes Distributed Active Archive ...
# 65   The Land Processes Distributed Active Archive ...
# 66   The Global Hyperspectral Imaging Spectral-libr...
# 67   \r\n\r\nThe Global Hyperspectral Imaging Spect...
# 68   The NASA Making Earth System Data Records for ...
# 69   The MYD17A2H Version 6 Gross Primary Productiv...
# 70   The MYD17A2H Version 6.1 Gross Primary Product...
# 71   The MYD17A2HGF Version 6 Gross Primary Product...
# 72   The MYD17A2HGF Version 6.1 Gross Primary Produ...
# 73   The MYD21 Land Surface Temperature and Emissiv...
# 74   The MYD21 Version 6.1 Land Surface Temperature...
# 75   A new suite of Moderate Resolution Imaging Spe...
# 76   A new suite of Moderate Resolution Imaging Spe...
# 77   A suite of Moderate Resolution Imaging Spectro...
# 78   A new suite of MODIS Land Surface Temperature ...
# 79   A new suite of MODIS Land Surface Temperature ...
# 80   A suite of MODIS Land Surface Temperature and ...
# 81   A new suite of Moderate Resolution Imaging Spe...
# 82   A suite of Moderate Resolution Imaging Spectro...
# 83   A new suite of Moderate Resolution Imaging Spe...
# 84   The MYD11_L2 Version 6 swath product provides ...
# 85   The MYD11_L2 Version 6.1 swath product provide...
# 86   The MYD11C2 Version 6 product provides  Land S...
# 87   The MYD11C2 Version 6.1 product provides  Land...
# 88   The MYD11A2 Version 6 product provides an aver...
# 89   The MYD11A2 Version 6.1 product provides an av...
# 90   The MYD11B2 Version 6 product provides an aver...
# 91   The MYD11B2 Version 6.1 product provides an av...
# 92   The MYD11C1 Version 6 product provides daily L...
# 93   The MYD11C1 Version 6.1 product provides daily...
# 94   The MYD11A1 Version 6 product provides daily p...
# 95   The MYD11A1 Version 6.1 product provides daily...
# 96   The MYD11B1 Version 6 product provides daily p...
# 97   The MYD11B1 Version 6.1 product provides daily...
# 98   The MYD11C3 Version 6 product provides monthly...
# 99   The MYD11C3 Version 6.1 product provides month...
# 100  The MYD11B3 Version 6 product provides average...
# 101  The MYD11B3 Version 6.1 product provides avera...
# 102  The MYD15A2H Version 6 Moderate Resolution Ima...
# 103  The MYD15A2H Version 6.1 Moderate Resolution I...
# 104  The MYD16A2 Version 6 Evapotranspiration/Laten...
# 105  The MYD16A2 Version 6.1 Evapotranspiration/Lat...
# 106  The MYD16A2GF Version 6 Evapotranspiration/Lat...
# 107  The MYD16A2GF Version 6.1 Evapotranspiration/L...
# 108  The MYD16A3GF Version 6 Evapotranspiration/Lat...
# 109  The MYD16A3GF Version 6.1 Evapotranspiration/L...
# 110  The MYD16A3 Version 6.1 Evapotranspiration/Lat...
# 111  The MYD17A3HGF Version 6 product provides info...
# 112  The MYD17A3HGF Version 6.1 product provides in...
# 113  The MYD17A3H Version 6 product provides inform...
# 114  The MYD17A3H Version 6.1 product provides info...
# 115  The MYDOCGA Version 6 Level 2 Gridded Lite (L2...
# 116  The MYD09Q1 Version 6 product provides an esti...
# 117  The MYD09Q1 Version 6.1 product provides an es...
# 118  The Moderate Resolition Imaging Spectroradiome...
# 119  The Moderate Resolution Imaging Spectroradiome...
# 120  The MYD09GA Version 6 product provides an esti...
# 121  The MYD09GA Version 6.1 product provides an es...
# 122  The MYD09GQ Version 6 product provides an esti...
# 123  The MYD09GQ Version 6.1 product provides an es...
# 124  The MYD09CMG Version 6 product provides an est...
# 125  The MYD09CMG Version 6.1 product provides an e...
# 126  The Aqua Moderate Resolution Imaging Spectrora...
# 127  The Aqua Moderate Resolution Imaging Spectrora...
# 128  The Aqua Moderate Resolution Imaging Spectrora...
# 129  The Aqua Moderate Resolution Imaging Spectrora...
# 130  The Aqua Moderate Resolution Imaging Spectrora...
# 131  The Aqua Moderate Resolution Imaging Spectrora...
# 132  The MYDTBGA Version 6 Moderate Resolution Imag...
# 133  The MYD13C1 Version 6 product provides a Veget...
# 134  The MYD13C1 Version 6.1 product provides a Veg...
# 135  The MYD13A2 Version 6 product provides Vegetat...
# 136  The MYD13A2 Version 6.1 product provides Veget...
# 137  The Aqua Moderate Resolution Imaging Spectrora...
# 138  The Aqua Moderate Resolution Imaging Spectrora...
# 139  The MYD13A1 Version 6 product provides Vegetat...
# 140  The MYD13A1 Version 6.1 product provides Veget...
# 141  The MYD13C2 Version 6 product provides a Veget...
# 142  The MYD13C2 Version 6.1 product provides a Veg...
# 143  The Aqua Moderate Resolution Imaging Spectrora...
# 144  The Aqua Moderate Resolution Imaging Spectrora...
# 145  The Aqua Moderate Resolution Imaging Spectrora...
# 146  The MOD17A2H Version 6 Gross Primary Productiv...
# 147  The MOD17A2H Version 6.1 Gross Primary Product...
# 148  The MOD17A2HGF Version 6 Gross Primary Product...
# 149  The MOD17A2HGF Version 6.1 Gross Primary Produ...
# 150  The MOD21 Land Surface Temperature and Emissiv...
# 151  The MOD21 Land Surface Temperature and Emissiv...
# 152  A suite of Moderate Resolution Imaging Spectro...
# 153  MODIS/Terra Land Surface Temperature/3-Band Em...
# 154  A suite of Moderate Resolution Imaging Spectro...
# 155  A suite of Moderate Resolution Imaging Spectro...
# 156  A new suite of Moderate Resolution Imaging Spe...
# 157  A suite of Moderate Resolution Imaging Spectro...
# 158  A new suite of Moderate Resolution Imaging Spe...
# 159  A suite of Moderate Resolution Imaging Spectro...
# 160  A suite of Moderate Resolution Imaging Spectro...
# 161  The MOD11_L2 Version 6 swath product provides ...
# 162  The MOD11_L2 Version 6.1 swath product provide...
# 163  The MOD11C2 Version 6 product provides  Land S...
# 164  The MOD11C2 Version 6.1 product provides  Land...
# 165  The MOD11A2 Version 6 product provides an aver...
# 166  The MOD11A2 Version 6.1 product provides an av...
# 167  The MOD11B2 Version 6 product provides an aver...
# 168  The MOD11B2 Version 6.1 product provides an av...
# 169  The MOD11C1 Version 6 product provides daily L...
# 170  The MOD11C1 Version 6.1 product provides daily...
# 171  The MOD11A1 Version 6 product provides daily p...
# 172  The MOD11A1 Version 6.1 product provides daily...
# 173  The MOD11B1 Version 6 product provides daily p...
# 174  The MOD11B1 Version 6.1 product provides daily...
# 175  The MOD11C3 Version 6 product provides monthly...
# 176  The MOD11C3 Version 6.1 product provides month...
# 177  The MOD11B3 version 6 product provides average...
# 178  The MOD11B3 Version 6.1 product provides avera...
# 179  The Terra Moderate Resolution Imaging Spectror...
# 180  The MOD15A2H Version 6 Moderate Resolution Ima...
# 181  The MOD15A2H Version 6.1 Moderate Resolution I...
# 182  The MOD16A2 Version 6 Evapotranspiration/Laten...
# 183  The MOD16A2 Version 6.1 Evapotranspiration/Lat...
# 184  The MOD16A2GF Version 6 Evapotranspiration/Lat...
# 185  The MOD16A2GF Version 6.1 Evapotranspiration/L...
# 186  The MOD16A3GF Version 6 Evapotranspiration/Lat...
# 187  The MOD16A3GF Version 6.1 Evapotranspiration/L...
# 188  The MOD16A3 Version 6.1 Evapotranspiration/Lat...
# 189  The MOD17A3HGF Version 6 product provides info...
# 190  The MOD17A2HGF Version 6.1 Gross Primary Produ...
# 191  The MOD17A3.055 dataset was decommissioned on ...
# 192  The MOD17A3H Version 6 product provides inform...
# 193  The MOD17A3H Version 6.1 product provides info...
# 194  The MODOCGA Version 6 Level 2 Gridded Lite (L2...
# 195  The MOD09Q1 Version 6 product provides an esti...
# 196  The MOD09Q1 Version 6.1 product provides an es...
# 197  The  Moderate Resolution Imaging Spectroradiom...
# 198  The  Moderate Resolution Imaging Spectroradiom...
# 199  The MOD09GA Version 6 product provides an esti...
#
#                                                  links  \
# 0    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 1    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 2    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 3    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 4    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 5    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 6    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 7    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 8    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 9    [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 10   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 11   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 12   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 13   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 14   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 15   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 16   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 17   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 18   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 19   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 20   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 21   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 22   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 23   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 24   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 25   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 26   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 27   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 28   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 29   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 30   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 31   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 32   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 33   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 34   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 35   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 36   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 37   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 38   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 39   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 40   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 41   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 42   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 43   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 44   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 45   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 46   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 47   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 48   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 49   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 50   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 51   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 52   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 53   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 54   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 55   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 56   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 57   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 58   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 59   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 60   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 61   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 62   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 63   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 64   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 65   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 66   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 67   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 68   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 69   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 70   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 71   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 72   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 73   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 74   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 75   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 76   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 77   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 78   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 79   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 80   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 81   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 82   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 83   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 84   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 85   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 86   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 87   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 88   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 89   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 90   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 91   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 92   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 93   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 94   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 95   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 96   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 97   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 98   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 99   [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 100  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 101  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 102  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 103  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 104  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 105  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 106  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 107  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 108  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 109  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 110  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 111  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 112  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 113  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 114  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 115  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 116  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 117  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 118  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 119  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 120  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 121  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 122  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 123  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 124  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 125  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 126  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 127  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 128  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 129  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 130  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 131  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 132  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 133  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 134  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 135  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 136  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 137  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 138  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 139  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 140  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 141  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 142  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 143  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 144  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 145  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 146  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 147  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 148  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 149  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 150  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 151  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 152  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 153  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 154  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 155  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 156  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 157  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 158  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 159  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 160  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 161  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 162  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 163  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 164  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 165  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 166  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 167  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 168  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 169  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 170  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 171  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 172  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 173  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 174  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 175  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 176  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 177  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 178  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 179  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 180  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 181  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 182  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 183  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 184  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 185  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 186  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 187  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 188  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 189  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 190  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 191  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 192  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 193  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 194  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 195  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 196  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 197  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 198  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 199  [{'rel': 'self', 'href': 'https://cmr.earthdat...
#
#                                                 extent
# 0    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 1    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 2    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 3    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 4    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 5    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 6    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 7    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 8    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 9    {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 10   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 11   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 12   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 13   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 14   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 15   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 16   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 17   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 18   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 19   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 20   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 21   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 22   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 23   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 24   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 25   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 26   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 27   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 28   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 29   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 30   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 31   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 32   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 33   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 34   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 35   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 36   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 37   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 38   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 39   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 40   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 41   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 42   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 43   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 44   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 45   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 46   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 47   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 48   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 49   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 50   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 51   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 52   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 53   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 54   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 55   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 56   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 57   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 58   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 59   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 60   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 61   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 62   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 63   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 64   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 65   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 66   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 67   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 68   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 69   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 70   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 71   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 72   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 73   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 74   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 75   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 76   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 77   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 78   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 79   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 80   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 81   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 82   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 83   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 84   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 85   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 86   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 87   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 88   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 89   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 90   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 91   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 92   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 93   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 94   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 95   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 96   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 97   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 98   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 99   {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 100  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 101  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 102  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 103  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 104  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 105  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 106  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 107  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 108  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 109  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 110  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 111  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 112  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 113  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 114  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 115  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 116  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 117  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 118  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 119  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 120  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 121  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 122  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 123  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 124  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 125  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 126  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 127  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 128  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 129  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 130  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 131  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 132  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 133  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 134  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 135  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 136  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 137  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 138  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 139  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 140  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 141  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 142  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 143  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 144  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 145  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 146  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 147  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 148  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 149  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 150  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 151  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 152  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 153  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 154  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 155  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 156  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 157  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 158  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 159  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 160  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 161  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 162  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 163  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 164  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 165  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 166  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 167  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 168  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 169  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 170  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 171  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 172  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 173  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 174  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 175  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 176  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 177  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 178  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 179  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 180  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 181  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 182  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 183  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 184  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 185  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 186  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 187  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 188  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 189  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 190  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 191  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 192  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 193  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 194  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 195  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 196  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 197  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 198  {'crs': 'http://www.opengis.net/def/crs/OGC/1....
# 199  {'crs': 'http://www.opengis.net/def/crs/OGC/1....

# %%
import os
from netrc import netrc
from subprocess import Popen
from getpass import getpass


data = 'hls'
if data == 'hls':
    #Setup NASA Credentials
    urs = 'urs.earthdata.nasa.gov'    # Earthdata URL to call for authentication
    prompts = ['Enter NASA Earthdata Login Username \n(or create an account at urs.earthdata.nasa.gov): ',
               'Enter NASA Earthdata Login Password: ']
    try:
        netrcDir = os.path.expanduser(r'C:\users\rscott\.netrc')
        #netrcDir = os.path.expanduser("~/.netrc")
        netrc(netrcDir).authenticators(urs)[0]
        del netrcDir

    # Below, create a netrc file and prompt user for NASA Earthdata Login Username and Password
    except FileNotFoundError:
        if 1 == 2:
            homeDir = os.path.expanduser("~")
            Popen('touch {0}.netrc | chmod og-rw {0}.netrc | echo machine {1} >> {0}.netrc'.format(homeDir + os.sep, urs), shell=True)
            Popen('echo login {} >> {}.netrc'.format(getpass(prompt=prompts[0]), homeDir + os.sep), shell=True)
            Popen('echo password {} >> {}.netrc'.format(getpass(prompt=prompts[1]), homeDir + os.sep), shell=True)
            del homeDir, urs, prompts

# %%
bbox = '-53.0172669999999968,-9.5331669999999988,-48.4956669999999974,-3.1035670000000000'                       
datetime='2020-04-23/2021-04-23', 

from satsearch import Search
results = Search(url='https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS',
                 #collections=['ASTGTM.v003'], 
                 #collections=['AST_09XT.v003'], 
                 collections=['AST_L1T.v003'], 
                 
                 
                 #bbox = '-53.0172669999999968,-9.5331669999999988,-48.4956669999999974,-3.1035670000000000' ,
                 bbox = '-74.5,40.2128,-73.5,41.2128' ,
                 datetime='2020-04-23/2021-04-23', 
                )

results.found()
# Out:
# 43

# %%
stac_items = Search(url='https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS',
                 collections=['AST_L1T.v003'], 
                 bbox = '-74.5,40.2128,-73.5,41.2128' ,                    
                 datetime='2020-04-23/2021-04-23', 
                ).items()

# %%
len(stac_items)
# Out:
# 43

# %%
stac_items[1].assets
# Out:
# {'04/AST_L1T_00305042020155106_20200505100108_3340': {'title': 'AST_L1T_00305042020155106_20200505100108_3340.hdf. MimeType: application/x-hdfeos',
#   'href': 'https://e4ftl01.cr.usgs.gov//ASTER_L1T/ASTT/AST_L1T.003/2020.05.04/AST_L1T_00305042020155106_20200505100108_3340.hdf',
#   'type': 'application/x-hdfeos'},
#  '04/AST_L1T_00305042020155106_20200505100108_3340_T': {'title': 'AST_L1T_00305042020155106_20200505100108_3340_T.tif. MimeType: application/x-geotiff',
#   'href': 'https://e4ftl01.cr.usgs.gov//ASTER_L1T/ASTT/AST_L1T.003/2020.05.04/AST_L1T_00305042020155106_20200505100108_3340_T.tif',
#   'type': 'application/x-geotiff'},
#  '04/AST_L1T_00305042020155106_20200505100108_3340_V': {'title': 'AST_L1T_00305042020155106_20200505100108_3340_V.tif. MimeType: application/x-geotiff',
#   'href': 'https://e4ftl01.cr.usgs.gov//ASTER_L1T/ASTT/AST_L1T.003/2020.05.04/AST_L1T_00305042020155106_20200505100108_3340_V.tif',
#   'type': 'application/x-geotiff'},
#  'browse': {'title': 'This Browse file may be downloaded directly from this link (BROWSE)',
#   'href': 'https://e4ftl01.cr.usgs.gov//WORKING/BRWS/Browse.001/2020.05.05/AST_L1T_00305042020155106_20200505100108_3340_BR.2.VNIR.jpg',
#   'type': 'image/jpeg'},
#  'metadata': {'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G1735268278-LPDAAC_ECS.xml',
#   'type': 'application/xml'}}

# %%
import copy
stac_new = copy.deepcopy(stac_items)

# %% [markdown]
# The asset band names are unique, so we don't want to have a list of 86 different band names but to combine by each, so we will remap them below to something common - e.g. 01, 02 could be V and T, etc.

# %%
for index, i in enumerate(stac_items):
    #print(i.assets)
    for k in i.assets:
        if '_T' in k:
            stac_new[index].assets['B01'] = stac_items[index].assets[k]
        if '_V' in k:
            stac_new[index].assets['B02'] = stac_items[index].assets[k]

# %%
stack = stackstac.stack(stac_new, epsg=6933, resolution=90, resampling=1, assets=['B01'])
#stack = stackstac.stack(stac_items, epsg=6933, resolution=30, resampling=1)

stack
# Out:
# <xarray.DataArray 'stackstac-c8e94f81cee3f714833741414c4f7d18' (time: 43, band: 1, y: 2457, x: 3141)>
# dask.array<fetch_raster_window, shape=(43, 1, 2457, 3141), dtype=float64, chunksize=(1, 1, 1024, 1024), chunktype=numpy.ndarray>
# Coordinates:
#   * time            (time) object 1588607457491000000 ... 1617637787785000000
#     id              (time) <U22 'G1735266801-LPDAAC_ECS' ... 'G2030472662-LPD...
#   * band            (band) <U3 'B01'
#   * x               (x) float64 -7.277e+06 -7.277e+06 ... -6.994e+06 -6.994e+06
#   * y               (y) float64 4.885e+06 4.885e+06 ... 4.664e+06 4.664e+06
#     end_datetime    (time) <U24 '2020-05-04T15:50:57.491Z' ... '2021-04-05T15...
#     start_datetime  (time) <U24 '2020-05-04T15:50:57.491Z' ... '2021-04-05T15...
# Attributes:
#     spec:        RasterSpec(epsg=6933, bounds=(-7276770, 4664160, -6994080, 4...
#     crs:         epsg:6933
#     transform:   | 90.00, 0.00,-7276770.00|\n| 0.00,-90.00, 4885290.00|\n| 0....
#     resolution:  90
