# %%
import requests
import pandas as pd

import intake
limit = 500

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
nasa = 'https://cmr.earthdata.nasa.gov/stac/'

response = requests.get(nasa)
json_response = response.json()

# %%
json_response = response.json()

# %%
#{'title': 'LARC_ASDC', 'rel': 'child', 'type': 'application/json', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC'}
collection_list = []
for collection in json_response["links"]:
    collection_list.append(collection)

# %%
datasets_list = []
for datasets in collection_list:
    url = datasets["href"]
    response = requests.get(url)
    json_response = response.json()
    datasets_list.append(json_response)
# Out:
# {'id': 'LARC_ASDC', 'title': 'LARC_ASDC', 'description': 'Root catalog for LARC_ASDC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACEPOL_AircraftRemoteSensing_AirHARP_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACEPOL_AircraftRemoteSensing_AirSPEX_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACEPOL_AircraftRemoteSensing_CPL_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACEPOL_MetNav_AircraftInSitu_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACEPOL_AircraftRemoteSensing_HSRL2_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACEPOL_AircraftRemoteSensing_RSP_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACRIMII_TSI_UARS_NAT.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACTIVATE_Aerosol_AircraftInSitu_Falcon_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACTIVATE_Cloud_AircraftInSitu_Falcon_Data.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/collections/ACTIVATE_TraceGas_AircraftInSitu_Falcon_Data.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC?page=2'}]}
# {'id': 'USGS_EROS', 'title': 'USGS_EROS', 'description': 'Root catalog for USGS_EROS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/EO1_ALI.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/EO1_Hyperion.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/ISERV.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/Landsat1-5_MSS_C1.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/Landsat4-5_TM_C1.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/Landsat7_ETM_Plus_C1.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/Landsat_8_OLI_TIRS_C1.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/MOSAICETM.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/ETMPAN.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS/collections/ETM.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS?page=2'}]}
# {'id': 'ESA', 'title': 'ESA', 'description': 'Root catalog for ESA', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/ADAM.Surface.Reflectance.Database.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/ALOS.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/ALOSIPY.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/ALOS.PALSAR.FBS.FBD.PLR.products.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/NASA_OMI.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/b673f41b-d934-49e4-af6b-44bbdf164367.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/936b319d-5253-425d-bd29-4b6ebce067ff.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/802569b8-fb56-4d78-a2e8-3e4549ff475b.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/3fe263d2-99ed-4751-b937-d26a31ab0606.vNA', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA/collections/ef6a9266-a210-4431-a4af-06cec4274726.vNA', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESA?page=2'}]}
# {'id': 'GHRC', 'title': 'GHRC', 'description': 'Root catalog for GHRC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'LAADS', 'title': 'LAADS', 'description': 'Root catalog for LAADS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MER_FRS_1P.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MCD06COSP_D3_MODIS.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MCD06COSP_M3_MODIS.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/COARE_cm_er2.mas.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MYDCSR_B.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MYD04_L2.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MYD04_3K.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MYD08_E3.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MYD08_D3.v6.1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS/collections/MYD08_M3.v6.1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS?page=2'}]}
# {'id': 'OBPG', 'title': 'OBPG', 'description': 'Root catalog for OBPG', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/OBPG', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/OBPG/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/OBPG/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'OB_DAAC', 'title': 'OB_DAAC', 'description': 'Root catalog for OB_DAAC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/2009oct_Chesapeake.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/AAOT.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/Academ_Kurchatov.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/ACE.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/ACE-ASIA.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/ACE-INC.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/ACIDD.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/Active_Fluorescence_2001.v0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/OCTS_L3b_CHL.v2014', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC/collections/OCTS_L3m_CHL.v2014', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC?page=2'}]}
# {'id': 'ECHO', 'title': 'ECHO', 'description': 'Root catalog for ECHO', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'ISRO', 'title': 'ISRO', 'description': 'Root catalog for ISRO', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/C1_PANA_STUC00GTD.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/C1_PANF_STUC00GTD.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/IMS1_HYSI_GEO.v1.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L1B_STD.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L1C_SGP.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L2B_CMK.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L2B_OLR.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L2B_HEM.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L2B_SST.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO/collections/3DIMG_L2B_UTH.vNot provided', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO?page=2'}]}
# {'id': 'LPCUMULUS', 'title': 'LPCUMULUS', 'description': 'Root catalog for LPCUMULUS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCUMULUS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCUMULUS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCUMULUS/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'EDF_DEV04', 'title': 'EDF_DEV04', 'description': 'Root catalog for EDF_DEV04', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/EDF_DEV04', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/EDF_DEV04/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/EDF_DEV04/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'GES_DISC', 'title': 'GES_DISC', 'description': 'Root catalog for GES_DISC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/ACOS_L2_Lite_FP.v7.3', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/ACOS_L2_Lite_FP.v9r', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/ACOS_L2S.v7.3', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/ACOS_L2S.v9r', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/AIRSM_CPR_MAT.v3.2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/AIRS_CPR_IND.v4.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/AIRS_CPR_MAT.v3.2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/AIRXAMAP.v005', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/AIRABRAD.v005', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC/collections/AIRXBCAL.v005', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC?page=2'}]}
# {'id': 'ASF', 'title': 'ASF', 'description': 'Root catalog for ASF', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_INT_JPG.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_POL_3FP.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_POL_SYN_3FP.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_C-DEM_STOKES.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_DEM.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_DEM_C.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_DEM_L.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_DEM_P.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_L-STOKES.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF/collections/AIRSAR_TOP_P-STOKES.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASF?page=2'}]}
# {'id': 'OMINRT', 'title': 'OMINRT', 'description': 'Root catalog for OMINRT', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/OMCLDRR.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/OMAERUV.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/OMTO3.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/OMTO3e.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/OMSO2.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/NMMIEAI-L2-NRT.v2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/NMTO3NRT.v2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/NPBUVO3-L2-NRT.v2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/NMSO2-PCA-L2-NRT.v2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT/collections/OMICOL3NRT.v3', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT?page=2'}]}
# {'id': 'EUMETSAT', 'title': 'EUMETSAT', 'description': 'Root catalog for EUMETSAT', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:CM:MSG:MSGASRE0100.v2015-06-01', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:DAT:METOP:OSI-104.v2011-09-28', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:DAT:METOP:ASCSZF1B.v2010-09-21', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:DAT:METOP:ASCSZR1B.v2010-09-21', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:DAT:METOP:ASCSZO1B.v2010-09-21', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:CM:METOP:ASCSZFR02.v2014-10-07', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:CM:METOP:ASCSZOR02.v2014-10-07', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:CM:METOP:ASCSZRR02.v2014-10-07', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:DAT:METOP:SOMO12.v2010-06-21', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT/collections/EO:EUM:DAT:METOP:SOMO25.v2010-06-21', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT?page=2'}]}
# {'id': 'NCCS', 'title': 'NCCS', 'description': 'Root catalog for NCCS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/NEX-DCP30.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/ GEOS-CF Products.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/GEOS FP.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/G5NR.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/GISS-CMIP5.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/GMAO-CMIP5.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS/collections/NEX-GDDP.v1', 'type': 'application/json'}]}
# {'id': 'NSIDCV0', 'title': 'NSIDCV0', 'description': 'Root catalog for NSIDCV0', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/NSIDC-0596.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/NSIDC-0326.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/NSIDC-0539.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD222.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD353.v6', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD239.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD249.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD23.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD632.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0/collections/GGD622.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0?page=2'}]}
# {'id': 'PODAAC', 'title': 'PODAAC', 'description': 'Root catalog for PODAAC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/ALES_L2_OST_ENVISAT_V1.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/ALES_L2_OST_JASON2_V1.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AMSRE_L3_SST_1DEG_1MO.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L2_SSS_CAP_V5.v5.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L3_SSS_RAINCORRECTED_CAP_7DAY_V5.v5.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L3_SSS_RAINCORRECTED_CAP_MONTHLY_V5.v5.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L3_SSS_CAP_7DAY_V5.v5.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L3_SSS_CAP_MONTHLY_V5.v5.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L3_WIND_SPEED_CAP_7DAY_V5.v5.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC/collections/AQUARIUS_L3_WIND_SPEED_CAP_MONTHLY_V5.v5.0', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC?page=2'}]}
# {'id': 'LARC', 'title': 'LARC', 'description': 'Root catalog for LARC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/ACR3L2DM.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/ACR3L2SC.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/MIANACP.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/MIANCAGP.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/MIANCARP.v2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/MISBR.v005', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/MIRCCMF.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/ATSMIGEO.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/GOMIGEO.v002', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC/collections/IXBMIGEO.v2', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LARC?page=2'}]}
# {'id': 'USGS', 'title': 'USGS', 'description': 'Root catalog for USGS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'SCIOPS', 'title': 'SCIOPS', 'description': 'Root catalog for SCIOPS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/USAP-1753101.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/latent-reserves-in-the-swiss-nfi.v1.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/KUKRI_He.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/NIPR_UAP_ELF_SYO.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/CH-OG-1-GPS-10S.v0.0', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/envidat-lwf-34.v2019-03-06', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/blue_ice_core_DML2004_AS.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/OES_CEOB_106_MILE.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/12_hourly_interpolated_surface_air_pressure_from_buoys.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS/collections/12-hourly_interpolated_surface_position_from_buoys.vNot provided', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS?page=2'}]}
# {'id': 'LANCEMODIS', 'title': 'LANCEMODIS', 'description': 'Root catalog for LANCEMODIS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/AM1EPHNE.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/PM1EPHND_NRT.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYDGB0.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD04_L2.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD04_3K.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD09CMA.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD09.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD021KM.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD02QKM.v6.1NRT', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS/collections/MYD02HKM.v6.1NRT', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS?page=2'}]}
# {'id': 'CDDIS', 'title': 'CDDIS', 'description': 'Root catalog for CDDIS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_SESES_MEASURES_PROD.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_data_cycle.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_data_rinex.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_products_geocenter.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_products_ionosphere.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_products_orbit.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_products_positions.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_products_quaternions.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_DORIS_products_stcd.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS/collections/CDDIS_GNSS_highrate_data.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS?page=2'}]}
# {'id': 'JAXA', 'title': 'JAXA', 'description': 'Root catalog for JAXA', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_AVNIR_Mul_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_AVNIR_Pan_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ND01020.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ND02009.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_OCTS_GAC_L1A_TI_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_OCTS_GAC_L1A_VNI_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_OCTS_GAC_L2_OC1_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_OCTS_GAC_L2_SST_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_OCTS_GAC_L2_VI_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA/collections/ADEOS_OCTS_GAC_L3B_Annual_OC_Latest Version.vLatest Version', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA?page=2'}]}
# {'id': 'AU_AADC', 'title': 'AU_AADC', 'description': 'Root catalog for AU_AADC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/ASAC_2201_HCL_0.5.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/LGB_10m_traverse.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/ASAC_2357.v2', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/mbs_wilhelm_msa_hooh.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/law_dome_annual_msa.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/Survey_1988_89_Mawson_npcms.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/200708_CEAMARC_CASO_TRACE_ELEMENT_SAMPLES.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/CEAMARC_CASO_200708030_EVENT_BATHYMETRY_PLOTS.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/CEAMARC_CASO_200708030_BIOGEOCHEMISTRYL_SAMPLES.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC/collections/CEAMARC_CASO_200708_V3_IMAGES.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC?page=2'}]}
# {'id': 'ECHO10_OPS', 'title': 'ECHO10_OPS', 'description': 'Root catalog for ECHO10_OPS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO10_OPS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO10_OPS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO10_OPS/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'LPDAAC_ECS', 'title': 'LPDAAC_ECS', 'description': 'Root catalog for LPDAAC_ECS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/AST14DEM.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/AST_L1AE.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/AST_L1BE.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/ASTGTM_NUMNC.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/ASTGTM_NC.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/AG1km.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/AG100.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/AG5KMMOH.v041', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/ASTWBD_ATTNC.v001', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections/ASTWBD_NC.v001', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS?page=2'}]}
# ...
# {'id': 'USGS_LTA', 'title': 'USGS_LTA', 'description': 'Root catalog for USGS_LTA', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/DLG100K.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/asas.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/APSF.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/EARTH_LAND_USGS_AMES_AIR_PHOTOS.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/AERIALDIGI.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/AK_AVHRR.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/aster_global_dem.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/AVHRR_GLOBAL_10-DAY_COMPOSITES.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/AVHRR_ORBITAL_SEGMENTS.vNot provided', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA/collections/CEOS_CalVal_Test_Sites-Algeria3.vNot provided', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA?page=2'}]}
# {'id': 'GESDISCCLD', 'title': 'GESDISCCLD', 'description': 'Root catalog for GESDISCCLD', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/GESDISCCLD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/GESDISCCLD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/GESDISCCLD/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'ASIPS', 'title': 'ASIPS', 'description': 'Root catalog for ASIPS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS/collections/CLDMSK_L2_VIIRS_NOAA20_NRT.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS/collections/CLDMSK_L2_VIIRS_SNPP_NRT.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS/collections/AERDT_L2_VIIRS_SNPP_NRT.v11', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS/collections/AERDB_L2_VIIRS_SNPP_NRT.v1', 'type': 'application/json'}]}
# {'id': 'ESDIS', 'title': 'ESDIS', 'description': 'Root catalog for ESDIS', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESDIS', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESDIS/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ESDIS/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'POCLOUD', 'title': 'POCLOUD', 'description': 'Root catalog for POCLOUD', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_ATM_STATE_05DEG_DAILY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_ATM_STATE_LLC0090GRID_DAILY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_ATM_STATE_05DEG_MONTHLY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_ATM_STATE_LLC0090GRID_MONTHLY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_DAILY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_MONTHLY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_BOLUS_05DEG_DAILY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_BOLUS_LLC0090GRID_DAILY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD/collections/ECCO_L4_BOLUS_LLC0090GRID_MONTHLY_V4R4.vV4r4', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD?page=2'}]}
# {'id': 'NSIDC_CPRD', 'title': 'NSIDC_CPRD', 'description': 'Root catalog for NSIDC_CPRD', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_CPRD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_CPRD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_CPRD/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'ORNL_CLOUD', 'title': 'ORNL_CLOUD', 'description': 'Root catalog for ORNL_CLOUD', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/Daymet_V4_Annual_Climatology_1852.v4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/Daymet_Daily_V4_1840.v4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/Daymet_V4_Monthly_Climatology_1855.v4', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_L3_AVIRIS_Biomass_1821.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_L3_AVIRIS_Sediment_1822.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_Sonar_Bathymetry_1807.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_UAVSAR_SLC_1816.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_L2_AirSWOT_1818.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_L2_AVIRIS_SR_1826.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD/collections/PreDeltaX_L3_AirSWOT_WL_1819.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD?page=2'}]}
# {'id': 'XYZ_PROV', 'title': 'XYZ_PROV', 'description': 'Root catalog for XYZ_PROV', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/XYZ_PROV', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/XYZ_PROV/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/XYZ_PROV/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'GHRC_DAAC', 'title': 'GHRC_DAAC', 'description': 'Root catalog for GHRC_DAAC', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/aces1am.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/aces1cont.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/aces1efm.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/aces1log.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/aces1time.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/aces1trig.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/amprimpacts.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/amsua15sp.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/amsua16sp.v1', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/collections/amsua17sp.v1', 'type': 'application/json'}, {'rel': 'next', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC?page=2'}]}
# {'id': 'CSDA', 'title': 'CSDA', 'description': 'Root catalog for CSDA', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/CSDA', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/CSDA/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/CSDA/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'MOPITT', 'title': 'MOPITT', 'description': 'Root catalog for MOPITT', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/MOPITT', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/MOPITT/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/MOPITT/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/MOPITT/collections/MOP02R_NRT.v5', 'type': 'application/json'}]}
# {'id': 'GHRC_CLOUD', 'title': 'GHRC_CLOUD', 'description': 'Root catalog for GHRC_CLOUD', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_CLOUD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_CLOUD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_CLOUD/search', 'title': 'Provider Item Search', 'type': 'application/json'}]}
# {'id': 'LPCLOUD', 'title': 'LPCLOUD', 'description': 'Root catalog for LPCLOUD', 'stac_version': '1.0.0-beta.2', 'links': [{'rel': 'self', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD', 'title': 'Provider catalog', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://cmr.earthdata.nasa.gov/stac/', 'title': 'Root catalog', 'type': 'application/json'}, {'rel': 'collections', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections', 'title': 'Provider Collections', 'type': 'application/json'}, {'rel': 'search', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search', 'title': 'Provider Item Search', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM.v003', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30.v1.5', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30.v1.5', 'type': 'application/json'}]}

# %%
#need to handling paging when more than one, this just a quick look to narrow down which collection ASTER in
collection_list = []
dataset_list = []
for dataset in datasets_list:
    df = pd.DataFrame([dataset])
    collection_list.append(df)
    
    for link in dataset["links"]:
        ldf = pd.DataFrame([link])
        ldf["id"] = dataset["id"]
        ldf = ldf.loc[ldf["rel"] == "child"]
        dataset_list.append(ldf)
    
dfCollections = pd.concat(collection_list)    

dfDataset = pd.concat(dataset_list)

# %%
dfCollections.head()
# Out:
#           id      title                 description  stac_version  \
# 0  LARC_ASDC  LARC_ASDC  Root catalog for LARC_ASDC  1.0.0-beta.2
# 0  USGS_EROS  USGS_EROS  Root catalog for USGS_EROS  1.0.0-beta.2
# 0        ESA        ESA        Root catalog for ESA  1.0.0-beta.2
# 0       GHRC       GHRC       Root catalog for GHRC  1.0.0-beta.2
# 0      LAADS      LAADS      Root catalog for LAADS  1.0.0-beta.2
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...
# 0  [{'rel': 'self', 'href': 'https://cmr.earthdat...

# %%
dfDataset.head()
# Out:
#      rel                                               href title  \
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
#
#                type         id
# 0  application/json  LARC_ASDC
# 0  application/json  LARC_ASDC
# 0  application/json  LARC_ASDC
# 0  application/json  LARC_ASDC
# 0  application/json  LARC_ASDC

# %%
dfDataset
# Out:
#       rel                                               href title  \
# 0   child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LARC_ASDC/...   NaN
# ..    ...                                                ...   ...
# 0   child  https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC/...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/MOPITT/col...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
# 0   child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
#
#                 type         id
# 0   application/json  LARC_ASDC
# 0   application/json  LARC_ASDC
# 0   application/json  LARC_ASDC
# 0   application/json  LARC_ASDC
# 0   application/json  LARC_ASDC
# ..               ...        ...
# 0   application/json  GHRC_DAAC
# 0   application/json     MOPITT
# 0   application/json    LPCLOUD
# 0   application/json    LPCLOUD
# 0   application/json    LPCLOUD
#
# [293 rows x 5 columns]

# %%
dfDataset.loc[dfDataset.href.str.contains("AST")]
# Out:
#      rel                                               href title  \
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS...   NaN
# 0  child  https://cmr.earthdata.nasa.gov/stac/LPCLOUD/co...   NaN
#
#                type          id
# 0  application/json  LPDAAC_ECS
# 0  application/json  LPDAAC_ECS
# 0  application/json  LPDAAC_ECS
# 0  application/json  LPDAAC_ECS
# 0  application/json  LPDAAC_ECS
# 0  application/json  LPDAAC_ECS
# 0  application/json  LPDAAC_ECS
# 0  application/json     LPCLOUD

# %%
cat2 = intake.open_stac_catalog(f'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections?limit={limit}')
col_info2 = pd.DataFrame(cat2.metadata['collections'])
col_info2.head(1)
# Out:
# ---------------------------------------------------------------------------
# STACError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\satstac\thing.py in open(cls, filename)
#      47             try:
# ---> 48                 dat = cls.open_remote(filename)
#      49             except STACError as err:
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\satstac\thing.py in open_remote(self, url, headers)
#      38         else:
# ---> 39             raise STACError('Unable to open %s' % url)
#      40         return json.loads(dat)
#
# STACError: Unable to open https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections?limit=500
#
# During handling of the above exception, another exception occurred:
#
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\connection.py in connect(self)
#     463                 )
# --> 464             _match_hostname(cert, self.assert_hostname or server_hostname)
#     465
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\connection.py in _match_hostname(cert, asserted_hostname)
#     511     try:
# --> 512         match_hostname(cert, asserted_hostname)
#     513     except CertificateError as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\ssl.py in match_hostname(cert, hostname)
#     415     if len(dnsnames) > 1:
# --> 416         raise CertificateError("hostname %r "
#     417             "doesn't match either of %s"
#
# SSLCertVerificationError: ("hostname 'cmr.earthdata.nasa.gov.s3.amazonaws.com' doesn't match either of '*.s3.amazonaws.com', 's3.amazonaws.com'",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='cmr.earthdata.nasa.gov.s3.amazonaws.com', port=443): Max retries exceeded with url: /stac/LPDAAC_ECS/collections?limit=500 (Caused by SSLError(SSLCertVerificationError("hostname 'cmr.earthdata.nasa.gov.s3.amazonaws.com' doesn't match either of '*.s3.amazonaws.com', 's3.amazonaws.com'")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-42-6dee5ca629e5> in <module>
# ----> 1 cat2 = intake.open_stac_catalog(f'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS/collections?limit={limit}')
#       2 col_info2 = pd.DataFrame(cat2.metadata['collections'])
#       3 col_info2.head(1)
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\intake_stac\catalog.py in __init__(self, stac_obj, **kwargs)
#      59             self._stac_obj = stac_obj
#      60         elif isinstance(stac_obj, str):
# ---> 61             self._stac_obj = self._stac_cls.open(stac_obj)
#      62         else:
#      63             raise ValueError('Expected %s instance, got: %s' % (self._stac_cls, type(stac_obj)))
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\satstac\thing.py in open(cls, filename)
#      50                 # try signed URL
#      51                 url, headers = get_s3_signed_url(filename)
# ---> 52                 dat = cls.open_remote(url, headers)
#      53         else:
#      54             if os.path.exists(filename):
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\satstac\thing.py in open_remote(self, url, headers)
#      33     def open_remote(self, url, headers={}):
#      34         """ Open remote file """
# ---> 35         resp = requests.get(url, headers=headers)
#      36         if resp.status_code == 200:
#      37             dat = resp.text
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\envs\stackstac\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='cmr.earthdata.nasa.gov.s3.amazonaws.com', port=443): Max retries exceeded with url: /stac/LPDAAC_ECS/collections?limit=500 (Caused by SSLError(SSLCertVerificationError("hostname 'cmr.earthdata.nasa.gov.s3.amazonaws.com' doesn't match either of '*.s3.amazonaws.com', 's3.amazonaws.com'")))
